# %%
import os
from dotenv import load_dotenv
from langchain_groq import ChatGroq

load_dotenv()  # reads GROQ_API_KEY from .env file in this folder

# Or set it directly here for quick demos:
# os.environ["GROQ_API_KEY"] = "your-key-here"

assert os.getenv("GROQ_API_KEY"), "Set GROQ_API_KEY in a .env file or above"
print("API key loaded")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import os
# ----> 2 from dotenv import load_dotenv
#       3 from langchain_groq import ChatGroq
#       4
#       5 load_dotenv()  # reads GROQ_API_KEY from .env file in this folder
#
# ModuleNotFoundError: No module named 'dotenv'

# %%
with open("blood_work.txt", "r") as f:
    blood_report = f.read()

print(blood_report[:200])
# Out:
# Patient: Rajesh Sharma, Age 48, Male
# Date: May 7, 2026
#
# COMPLETE BLOOD COUNT (CBC)
# --------------------------
# Hemoglobin:        15.1 g/dL        (Normal: 13.5–17.5)
# Hematocrit:        44%

# %%
llm = ChatGroq(model="qwen/qwen3-32b", reasoning_format="parsed")

extraction_prompt = f"""
You are a medical data extraction assistant.

From the blood report below, extract ALL test values and classify each one as HIGH, LOW, or NORMAL 
based on the reference ranges provided in the report.

Format your response as:
- Test Name: value | Status: HIGH/LOW/NORMAL | Reference: range 

Blood Report:
{blood_report}
"""

extraction_response = llm.invoke(extraction_prompt)
extracted_values = extraction_response.text

print("=== STAGE 1: EXTRACTED VALUES ===")
print(extracted_values)
# Out:
# === STAGE 1: EXTRACTED VALUES ===
# - Test Name: Hemoglobin | Status: NORMAL | Reference: 13.5–17.5 g/dL
# - Test Name: Hematocrit | Status: NORMAL | Reference: 41–53%
# - Test Name: WBC | Status: NORMAL | Reference: 4.5–11.0 x10^3/uL
# - Test Name: Platelets | Status: NORMAL | Reference: 150–400 x10^3/uL
# - Test Name: Total Cholesterol | Status: HIGH | Reference: <200 mg/dL
# - Test Name: LDL Cholesterol | Status: HIGH | Reference: <100 mg/dL
# - Test Name: HDL Cholesterol | Status: LOW | Reference: >40 mg/dL
# - Test Name: Triglycerides | Status: HIGH | Reference: <150 mg/dL
# - Test Name: Glucose (Fasting) | Status: NORMAL | Reference: 70–99 mg/dL
# - Test Name: HbA1c | Status: NORMAL | Reference: <5.7%
# - Test Name: Creatinine | Status: NORMAL | Reference: 0.7–1.3 mg/dL
# - Test Name: eGFR | Status: NORMAL | Reference: >60 mL/min
# - Test Name: ALT | Status: NORMAL | Reference: 7–40 U/L
# - Test Name: AST | Status: NORMAL | Reference: 10–40 U/L
# - Test Name: Bilirubin Total | Status: NORMAL | Reference: 0.2–1.2 mg/dL

# %%
diet_prompt = f"""
You are a clinical nutritionist specializing in Indian dietary habits.

Based on the blood work analysis below, write:
1. A short health summary in 4-5 lines explaining the patient's condition in simple language
2. A short, practical Indian diet plan having only two sections (1) Foods to avoid (2) Foods to eat more of. 
   Do not include any other sections in diet plan.

Blood Work Analysis:
{extracted_values}
"""

diet_response = llm.invoke(diet_prompt)

print("=== STAGE 2: HEALTH SUMMARY & DIET PLAN ===")
print(diet_response.text)
# Out:
# === STAGE 2: HEALTH SUMMARY & DIET PLAN ===
# **Health Summary:**
# Your blood work shows normal overall health, but your cholesterol levels are a concern. Total cholesterol, LDL ("bad" cholesterol), and triglycerides are high, while HDL ("good" cholesterol) is low. This imbalance increases the risk of heart disease and requires dietary changes to improve lipid levels. Other markers like blood sugar, kidney function, and liver enzymes are within healthy ranges.
#
# **Indian Diet Plan:**
# **(1) Foods to avoid:**
# - Deep-fried snacks (e.g., pakoras, vadas), ghee/clarified butter, dalda, and processed oils.
# - Refined flours (maida), white rice, and sugary beverages (e.g., thanda, soft drinks).
#
# **(2) Foods to eat more of:**
# - Whole grains: Oats, brown rice, whole wheat (roti), quinoa.
# - Fruits: Apples, pomegranate, guava, and berries (if available).
# - Vegetables: Leafy greens (spinach, methi), carrots, and broccoli.
# - Healthy fats: Nuts (almonds, walnuts), flaxseeds, and olive oil.
# - Legumes: Moong dal, chana, and lentils for fiber.
# - Spices: Turmeric, cumin, and garlic to reduce inflammation.
# - Hydration: Add lemon or coriander to water; avoid sugary drinks.
