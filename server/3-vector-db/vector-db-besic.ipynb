# %%
import chromadb
client = chromadb.Client()

# %%
collection = client.create_collection("news")

# %%
collection.add(
    ids=["id1", "id2", "id3", "id4"],
    documents=[
        "Apple is leading in a smart phone game with iPhone sales up by 35%",
        "Tesla booked a minor profit of 1 billion $ in Q2",
        "Apples are high in fiber, vitamin C, and various antioxidants",
        "SpaceX got NASA contract worth 10 billion $",
    ]
)
# Out:
# /Users/somnathdas/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|█| 79.3M/79.3M [00:11<00:00, 7.49MiB/s

# %%
data = collection.get(include=["documents", "embeddings", "metadatas"])
for i, emb in enumerate(data["embeddings"]):
    print(f"\nDocument {i+1}")
    print("Text", data["documents"][i])
    print("Embedding length:", len(emb))
    print("First 10 values", emb[:10])
# Out:
# Document 1
# Text Apple is leading in a smart phone game with iPhone sales up by 35%
# Embedding length: 384
# First 10 values [ 0.03640459  0.01021044  0.08642429 -0.12735227 -0.01895927  0.00309626
#   0.01671751  0.05566163  0.02376827  0.11325457]
#
# Document 2
# Text Tesla booked a minor profit of 1 billion $ in Q2
# Embedding length: 384
# First 10 values [ 0.03228295  0.08888531  0.02695827  0.07444265 -0.06773709 -0.03529558
#  -0.02407436  0.10166309  0.0228303   0.02386423]
#
# Document 3
# Text Apples are high in fiber, vitamin C, and various antioxidants
# Embedding length: 384
# First 10 values [ 0.0451243  -0.0314501   0.01100097  0.080589    0.0011994   0.02187004
#  -0.00926966 -0.01325596  0.00425179  0.02350496]
#
# Document 4
# Text SpaceX got NASA contract worth 10 billion $
# Embedding length: 384
# First 10 values [-0.02309863  0.03526216  0.06101781 -0.0273439  -0.08042091 -0.02970158
#   0.07421497  0.05592687  0.02907894  0.07048373]

# %%
results = collection.query(
    query_texts=["This is a query related to Elon Musk"],
    n_results=2
)
print(results)
# Out:
# {'ids': [['id2', 'id4']], 'embeddings': None, 'documents': [['Tesla booked a minor profit of 1 billion $ in Q2', 'SpaceX got NASA contract worth 10 billion $']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None, None]], 'distances': [[1.5166926383972168, 1.5598336458206177]]}

# %%
results = collection.query(
    query_texts=["I love iPad"],
    n_results=2
)
print(results)
# Out:
# {'ids': [['id1', 'id3']], 'embeddings': None, 'documents': [['Apple is leading in a smart phone game with iPhone sales up by 35%', 'Apples are high in fiber, vitamin C, and various antioxidants']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None, None]], 'distances': [[1.4372704029083252, 1.669585943222046]]}

# %%
results = collection.query(
    query_texts=["Tips for improving health"],
    n_results=2
)
print(results)
# Out:
# {'ids': [['id3', 'id1']], 'embeddings': None, 'documents': [['Apples are high in fiber, vitamin C, and various antioxidants', 'Apple is leading in a smart phone game with iPhone sales up by 35%']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None, None]], 'distances': [[1.5245025157928467, 1.9163596630096436]]}
